# %%
from nba_api.stats.static import teams
import pandas as pd
from tqdm import tqdm

# %%
teams.get_teams()
# Out:
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Georgia',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966},
#  {'id': 1610612742,
#   'full_name': 'Dallas Mavericks',
#   'abbreviation': 'DAL',
#   'nickname': 'Mavericks',
#   'city': 'Dallas',
#   'state': 'Texas',
#   'year_founded': 1980},
#  {'id': 1610612743,
#   'full_name': 'Denver Nuggets',
#   'abbreviation': 'DEN',
#   'nickname': 'Nuggets',
#   'city': 'Denver',
#   'state': 'Colorado',
#   'year_founded': 1976},
#  {'id': 1610612744,
#   'full_name': 'Golden State Warriors',
#   'abbreviation': 'GSW',
#   'nickname': 'Warriors',
#   'city': 'Golden State',
#   'state': 'California',
#   'year_founded': 1946},
#  {'id': 1610612745,
#   'full_name': 'Houston Rockets',
#   'abbreviation': 'HOU',
#   'nickname': 'Rockets',
#   'city': 'Houston',
#   'state': 'Texas',
#   'year_founded': 1967},
#  {'id': 1610612746,
#   'full_name': 'Los Angeles Clippers',
#   'abbreviation': 'LAC',
#   'nickname': 'Clippers',
#   'city': 'Los Angeles',
#   'state': 'California',
#   'year_founded': 1970},
#  {'id': 1610612747,
#   'full_name': 'Los Angeles Lakers',
#   'abbreviation': 'LAL',
#   'nickname': 'Lakers',
#   'city': 'Los Angeles',
#   'state': 'California',
#   'year_founded': 1948},
#  {'id': 1610612748,
#   'full_name': 'Miami Heat',
#   'abbreviation': 'MIA',
#   'nickname': 'Heat',
#   'city': 'Miami',
#   'state': 'Florida',
#   'year_founded': 1988},
#  {'id': 1610612749,
#   'full_name': 'Milwaukee Bucks',
#   'abbreviation': 'MIL',
#   'nickname': 'Bucks',
#   'city': 'Milwaukee',
#   'state': 'Wisconsin',
#   'year_founded': 1968},
#  {'id': 1610612750,
#   'full_name': 'Minnesota Timberwolves',
#   'abbreviation': 'MIN',
#   'nickname': 'Timberwolves',
#   'city': 'Minnesota',
#   'state': 'Minnesota',
#   'year_founded': 1989},
#  {'id': 1610612751,
#   'full_name': 'Brooklyn Nets',
#   'abbreviation': 'BKN',
#   'nickname': 'Nets',
#   'city': 'Brooklyn',
#   'state': 'New York',
#   'year_founded': 1976},
#  {'id': 1610612752,
#   'full_name': 'New York Knicks',
#   'abbreviation': 'NYK',
#   'nickname': 'Knicks',
#   'city': 'New York',
#   'state': 'New York',
#   'year_founded': 1946},
#  {'id': 1610612753,
#   'full_name': 'Orlando Magic',
#   'abbreviation': 'ORL',
#   'nickname': 'Magic',
#   'city': 'Orlando',
#   'state': 'Florida',
#   'year_founded': 1989},
#  {'id': 1610612754,
#   'full_name': 'Indiana Pacers',
#   'abbreviation': 'IND',
#   'nickname': 'Pacers',
#   'city': 'Indiana',
#   'state': 'Indiana',
#   'year_founded': 1976},
#  {'id': 1610612755,
#   'full_name': 'Philadelphia 76ers',
#   'abbreviation': 'PHI',
#   'nickname': '76ers',
#   'city': 'Philadelphia',
#   'state': 'Pennsylvania',
#   'year_founded': 1949},
#  {'id': 1610612756,
#   'full_name': 'Phoenix Suns',
#   'abbreviation': 'PHX',
#   'nickname': 'Suns',
#   'city': 'Phoenix',
#   'state': 'Arizona',
#   'year_founded': 1968},
#  {'id': 1610612757,
#   'full_name': 'Portland Trail Blazers',
#   'abbreviation': 'POR',
#   'nickname': 'Trail Blazers',
#   'city': 'Portland',
#   'state': 'Oregon',
#   'year_founded': 1970},
#  {'id': 1610612758,
#   'full_name': 'Sacramento Kings',
#   'abbreviation': 'SAC',
#   'nickname': 'Kings',
#   'city': 'Sacramento',
#   'state': 'California',
#   'year_founded': 1948},
#  {'id': 1610612759,
#   'full_name': 'San Antonio Spurs',
#   'abbreviation': 'SAS',
#   'nickname': 'Spurs',
#   'city': 'San Antonio',
#   'state': 'Texas',
#   'year_founded': 1976},
#  {'id': 1610612760,
#   'full_name': 'Oklahoma City Thunder',
#   'abbreviation': 'OKC',
#   'nickname': 'Thunder',
#   'city': 'Oklahoma City',
#   'state': 'Oklahoma',
#   'year_founded': 1967},
#  {'id': 1610612761,
#   'full_name': 'Toronto Raptors',
#   'abbreviation': 'TOR',
#   'nickname': 'Raptors',
#   'city': 'Toronto',
#   'state': 'Ontario',
#   'year_founded': 1995},
#  {'id': 1610612762,
#   'full_name': 'Utah Jazz',
#   'abbreviation': 'UTA',
#   'nickname': 'Jazz',
#   'city': 'Utah',
#   'state': 'Utah',
#   'year_founded': 1974},
#  {'id': 1610612763,
#   'full_name': 'Memphis Grizzlies',
#   'abbreviation': 'MEM',
#   'nickname': 'Grizzlies',
#   'city': 'Memphis',
#   'state': 'Tennessee',
#   'year_founded': 1995},
#  {'id': 1610612764,
#   'full_name': 'Washington Wizards',
#   'abbreviation': 'WAS',
#   'nickname': 'Wizards',
#   'city': 'Washington',
#   'state': 'District of Columbia',
#   'year_founded': 1961},
#  {'id': 1610612765,
#   'full_name': 'Detroit Pistons',
#   'abbreviation': 'DET',
#   'nickname': 'Pistons',
#   'city': 'Detroit',
#   'state': 'Michigan',
#   'year_founded': 1948},
#  {'id': 1610612766,
#   'full_name': 'Charlotte Hornets',
#   'abbreviation': 'CHA',
#   'nickname': 'Hornets',
#   'city': 'Charlotte',
#   'state': 'North Carolina',
#   'year_founded': 1988}]

# %%
db_path = "./database/"

def teams_table():
    pd.DataFrame(teams.get_teams()).to_csv(db_path + "teams.csv", index=False)

teams_table()

# %%
from nba_api.stats.static import players

def players_table():
    pd.DataFrame(players.get_players()).to_csv(db_path + "players.csv", index=False)

players_table()

# %%
from nba_api.stats.endpoints import leaguegamefinder

leaguegamefinder.LeagueGameFinder(player_or_team_abbreviation="Lebron James").get_data_frame()

# %%
from nba_api.stats.endpoints import teamgamelog

a = teamgamelog.TeamGameLog(season="1960-61",season_type_all_star="Regular Season",team_id=1610612738).get_dict()
a
# Out:
# {'resource': 'teamgamelog',
#  'parameters': {'TeamID': 1610612738,
#   'LeagueID': None,
#   'Season': '1960-61',
#   'SeasonType': 'Regular Season',
#   'DateFrom': None,
#   'DateTo': None},
#  'resultSets': [{'name': 'TeamGameLog',
#    'headers': ['Team_ID',
#     'Game_ID',
#     'GAME_DATE',
#     'MATCHUP',
#     'WL',
#     'W',
#     'L',
#     'W_PCT',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS'],
#    'rowSet': [[1610612738,
#      '0026000314',
#      'MAR 12, 1961',
#      'BOS @ SYR',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      50,
#      None,
#      None,
#      None,
#      None,
#      None,
#      36,
#      None,
#      None,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      28,
#      136],
#     [1610612738,
#      '0026000311',
#      'MAR 11, 1961',
#      'BOS vs. SYR',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      49,
#      None,
#      None,
#      None,
#      None,
#      None,
#      28,
#      47,
#      0.596,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      25,
#      126],
#     [1610612738,
#      '0026000309',
#      'MAR 09, 1961',
#      'BOS vs. DET',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      46,
#      None,
#      None,
#      None,
#      None,
#      None,
#      27,
#      36,
#      0.75,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      23,
#      119],
#     [1610612738,
#      '0026000304',
#      'MAR 08, 1961',
#      'BOS vs. SYR',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      50,
#      None,
#      None,
#      None,
#      None,
#      None,
#      36,
#      43,
#      0.837,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      20,
#      136],
#     [1610612738,
#      '0026000302',
#      'MAR 07, 1961',
#      'BOS vs. CIN',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      47,
#      None,
#      None,
#      None,
#      None,
#      None,
#      30,
#      None,
#      None,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      20,
#      124],
#     [1610612738,
#      '0026000297',
#      'MAR 05, 1961',
#      'BOS vs. PHW',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      66,
#      None,
#      None,
#      None,
#      None,
#      None,
#      14,
#      None,
#      None,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      25,
#      146],
#     [1610612738,
#      '0026000295',
#      'MAR 04, 1961',
#      'BOS vs. NYK',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      42,
#      None,
#      None,
#      None,
#      None,
#      None,
#      29,
#      None,
#      None,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      23,
#      113],
#     [1610612738,
#      '0026000290',
#      'MAR 01, 1961',
#      'BOS vs. STL',
#      'L',
#      None,
#      None,
#      None,
#      0,
#      38,
#      None,
#      None,
#      None,
#      None,
#      None,
#      21,
#      35,
#      0.6,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      27,
#      97],
#     [1610612738,
#      '0026000284',
#      'FEB 28, 1961',
#      'BOS @ NYK',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      57,
#      None,
#      None,
#      None,
#      None,
#      None,
#      28,
#      36,
#      0.778,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      23,
#      142],
#     [1610612738,
#      '0026000282',
#      'FEB 26, 1961',
#      'BOS @ DET',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      45,
#      None,
#      None,
#      None,
#      None,
#      None,
#      23,
#      32,
#      0.719,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      23,
#      113],
#     [1610612738,
#      '0026000278',
#      'FEB 25, 1961',
#      'BOS @ STL',
#      'W',
#      None,
#      None,
#      None,
#      240,
#      49,
#      111,
#      0.441,
#      None,
#      None,
#      None,
#      24,
#      30,
#      0.8,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      27,
#      122],
#     [1610612738,
#      '0026000275',
#      'FEB 24, 1961',
#      'BOS vs. SYR',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      56,
#      None,
#      None,
#      None,
#      None,
#      None,
#      32,
#      42,
#      0.762,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      26,
#      144],
#     [1610612738,
#      '0026000272',
#      'FEB 22, 1961',
#      'BOS @ LAL',
#      'L',
#      None,
#      None,
#      None,
#      0,
#      33,
#      None,
#      None,
#      None,
#      None,
#      None,
#      27,
#      34,
#      0.794,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      23,
#      93],
#     [1610612738,
#      '0026000264',
#      'FEB 19, 1961',
#      'BOS @ SYR',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      42,
#      None,
#      None,
#      None,
#      None,
#      None,
#      32,
#      43,
#      0.744,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      29,
#      116],
#     [1610612738,
#      '0026000258',
#      'FEB 17, 1961',
#      'BOS @ PHW',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      51,
#      None,
#      None,
#      None,
#      None,
#      None,
#      31,
#      None,
#      None,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      30,
#      133],
#     [1610612738,
#      '0026000255',
#      'FEB 16, 1961',
#      'BOS @ PHW',
#      'L',
#      None,
#      None,
#      None,
#      0,
#      38,
#      None,
#      None,
#      None,
#      None,
#      None,
#      35,
#      None,
#      None,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      111],
#     [1610612738,
#      '0026000251',
#      'FEB 14, 1961',
#      'BOS vs. LAL',
#      'W',
#      None,
#      None,
#      None,
#      240,
#      46,
#      96,
#      0.479,
#      None,
#      None,
#      None,
#      21,
#      33,
#      0.636,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      25,
#      113],
#     [1610612738,
#      '0026000245',
#      'FEB 12, 1961',
#      'BOS vs. PHW',
#      'W',
#      None,
#      None,
#      None,
#      240,
#      55,
#      127,
#      0.433,
#      0,
#      0,
#      None,
#      26,
#      34,
#      0.765,
#      0,
#      None,
#      0,
#      33,
#      0,
#      0,
#      0,
#      28,
#      136],
#     [1610612738,
#      '0026000244',
#      'FEB 11, 1961',
#      'BOS vs. NYK',
#      'L',
#      None,
#      None,
#      None,
#      240,
#      43,
#      126,
#      0.341,
#      0,
#      0,
#      None,
#      21,
#      26,
#      0.808,
#      0,
#      None,
#      0,
#      18,
#      0,
#      0,
#      0,
#      35,
#      107],
#     [1610612738,
#      '0026000240',
#      'FEB 10, 1961',
#      'BOS @ DET',
#      'L',
#      None,
#      None,
#      None,
#      0,
#      54,
#      None,
#      None,
#      None,
#      None,
#      None,
#      26,
#      38,
#      0.684,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      35,
#      134],
#     [1610612738,
#      '0026000235',
#      'FEB 08, 1961',
#      'BOS @ SYR',
#      'L',
#      None,
#      None,
#      None,
#      240,
#      42,
#      108,
#      0.389,
#      0,
#      0,
#      None,
#      24,
#      41,
#      0.585,
#      0,
#      None,
#      0,
#      13,
#      0,
#      0,
#      0,
#      0,
#      108],
#     [1610612738,
#      '0026000233',
#      'FEB 07, 1961',
#      'BOS vs. LAL',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      37,
#      None,
#      None,
#      None,
#      None,
#      None,
#      22,
#      35,
#      0.629,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      29,
#      96],
#     [1610612738,
#      '0026000227',
#      'FEB 05, 1961',
#      'BOS vs. STL',
#      'W',
#      None,
#      None,
#      None,
#      240,
#      50,
#      123,
#      0.407,
#      0,
#      0,
#      None,
#      23,
#      31,
#      0.742,
#      0,
#      None,
#      0,
#      26,
#      0,
#      0,
#      0,
#      26,
#      123],
#     [1610612738,
#      '0026000223',
#      'FEB 03, 1961',
#      'BOS vs. NYK',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      46,
#      None,
#      None,
#      None,
#      None,
#      None,
#      31,
#      44,
#      0.705,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      23,
#      123],
#     [1610612738,
#      '0026000217',
#      'FEB 01, 1961',
#      'BOS vs. NYK',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      46,
#      None,
#      None,
#      None,
#      None,
#      None,
#      32,
#      49,
#      0.653,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      21,
#      124],
#     [1610612738,
#      '0026000215',
#      'JAN 31, 1961',
#      'BOS @ STL',
#      'W',
#      None,
#      None,
#      None,
#      240,
#      43,
#      117,
#      0.368,
#      None,
#      None,
#      None,
#      23,
#      33,
#      0.697,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      23,
#      109],
#     [1610612738,
#      '0026000212',
#      'JAN 30, 1961',
#      'BOS @ CIN',
#      'L',
#      None,
#      None,
#      None,
#      0,
#      35,
#      121,
#      0.289,
#      None,
#      None,
#      None,
#      18,
#      37,
#      0.486,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      0,
#      88],
#     [1610612738,
#      '0026000208',
#      'JAN 29, 1961',
#      'BOS vs. PHW',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      52,
#      None,
#      None,
#      None,
#      None,
#      None,
#      24,
#      None,
#      None,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      26,
#      128],
#     [1610612738,
#      '0026000205',
#      'JAN 27, 1961',
#      'BOS vs. DET',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      62,
#      None,
#      None,
#      None,
#      None,
#      None,
#      16,
#      None,
#      None,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      23,
#      140],
#     [1610612738,
#      '0026000202',
#      'JAN 26, 1961',
#      'BOS @ PHW',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      49,
#      None,
#      None,
#      None,
#      None,
#      None,
#      31,
#      None,
#      None,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      28,
#      129],
#     [1610612738,
#      '0026000196',
#      'JAN 24, 1961',
#      'BOS @ NYK',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      51,
#      None,
#      None,
#      None,
#      None,
#      None,
#      23,
#      None,
#      None,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      125],
#     [1610612738,
#      '0026000188',
#      'JAN 21, 1961',
#      'BOS @ SYR',
#      'L',
#      None,
#      None,
#      None,
#      0,
#      45,
#      None,
#      None,
#      None,
#      None,
#      None,
#      34,
#      None,
#      None,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      32,
#      124],
#     [1610612738,
#      '0026000186',
#      'JAN 19, 1961',
#      'BOS vs. LAL',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      44,
#      None,
#      None,
#      None,
#      None,
#      None,
#      18,
#      25,
#      0.72,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      20,
#      106],
#     [1610612738,
#      '0026000183',
#      'JAN 18, 1961',
#      'BOS vs. STL',
#      'L',
#      None,
#      None,
#      None,
#      240,
#      46,
#      129,
#      0.357,
#      None,
#      None,
#      None,
#      22,
#      31,
#      0.71,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      27,
#      114],
#     [1610612738,
#      '0026000177',
#      'JAN 15, 1961',
#      'BOS vs. NYK',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      54,
#      None,
#      None,
#      None,
#      None,
#      None,
#      34,
#      42,
#      0.81,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      22,
#      142],
#     [1610612738,
#      '0026000175',
#      'JAN 14, 1961',
#      'BOS @ PHW',
#      'L',
#      None,
#      None,
#      None,
#      0,
#      43,
#      None,
#      None,
#      None,
#      None,
#      None,
#      27,
#      31,
#      0.871,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      113],
#     [1610612738,
#      '0026000172',
#      'JAN 13, 1961',
#      'BOS vs. PHW',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      52,
#      None,
#      None,
#      None,
#      None,
#      None,
#      19,
#      None,
#      None,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      28,
#      123],
#     [1610612738,
#      '0026000169',
#      'JAN 12, 1961',
#      'BOS vs. SYR',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      53,
#      None,
#      None,
#      None,
#      None,
#      None,
#      18,
#      25,
#      0.72,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      27,
#      124],
#     [1610612738,
#      '0026000165',
#      'JAN 10, 1961',
#      'BOS vs. DET',
#      'W',
#      None,
#      None,
#      None,
#      240,
#      44,
#      110,
#      0.4,
#      None,
#      None,
#      None,
#      30,
#      44,
#      0.682,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      29,
#      118],
#     [1610612738,
#      '0026000162',
#      'JAN 08, 1961',
#      'BOS @ STL',
#      'L',
#      None,
#      None,
#      None,
#      240,
#      41,
#      113,
#      0.363,
#      None,
#      None,
#      None,
#      22,
#      31,
#      0.71,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      28,
#      104],
#     [1610612738,
#      '0026000158',
#      'JAN 06, 1961',
#      'BOS @ DET',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      37,
#      None,
#      None,
#      None,
#      None,
#      None,
#      34,
#      47,
#      0.723,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      23,
#      108],
#     [1610612738,
#      '0026000154',
#      'JAN 05, 1961',
#      'BOS @ CIN',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      47,
#      None,
#      None,
#      None,
#      None,
#      None,
#      31,
#      37,
#      0.838,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      27,
#      125],
#     [1610612738,
#      '0026000151',
#      'JAN 03, 1961',
#      'BOS @ LAL',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      39,
#      None,
#      None,
#      None,
#      None,
#      None,
#      24,
#      29,
#      0.828,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      24,
#      102],
#     [1610612738,
#      '0026000145',
#      'JAN 01, 1961',
#      'BOS @ SYR',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      45,
#      None,
#      None,
#      None,
#      None,
#      None,
#      23,
#      None,
#      None,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      113],
#     [1610612738,
#      '0026000141',
#      'DEC 30, 1960',
#      'BOS @ NYK',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      46,
#      None,
#      None,
#      None,
#      None,
#      None,
#      28,
#      34,
#      0.824,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      25,
#      120],
#     [1610612738,
#      '0026000135',
#      'DEC 28, 1960',
#      'BOS @ STL',
#      'L',
#      None,
#      None,
#      None,
#      240,
#      36,
#      108,
#      0.333,
#      None,
#      None,
#      None,
#      27,
#      34,
#      0.794,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      26,
#      99],
#     [1610612738,
#      '0026000132',
#      'DEC 27, 1960',
#      'BOS @ PHW',
#      'L',
#      None,
#      None,
#      None,
#      0,
#      39,
#      None,
#      None,
#      None,
#      None,
#      None,
#      23,
#      28,
#      0.821,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      29,
#      101],
#     [1610612738,
#      '0026000128',
#      'DEC 26, 1960',
#      'BOS vs. PHW',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      49,
#      None,
#      None,
#      None,
#      None,
#      None,
#      21,
#      33,
#      0.636,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      30,
#      119],
#     [1610612738,
#      '0026000124',
#      'DEC 24, 1960',
#      'BOS vs. DET',
#      'W',
#      None,
#      None,
#      None,
#      240,
#      61,
#      146,
#      0.418,
#      0,
#      0,
#      None,
#      28,
#      34,
#      0.824,
#      0,
#      None,
#      0,
#      31,
#      0,
#      0,
#      0,
#      19,
#      150],
#     [1610612738,
#      '0026000123',
#      'DEC 21, 1960',
#      'BOS vs. STL',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      49,
#      None,
#      None,
#      None,
#      None,
#      None,
#      22,
#      30,
#      0.733,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      25,
#      120],
#     [1610612738,
#      '0026000119',
#      'DEC 20, 1960',
#      'BOS vs. CIN',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      47,
#      None,
#      None,
#      None,
#      None,
#      None,
#      21,
#      29,
#      0.724,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      24,
#      115],
#     [1610612738,
#      '0026000114',
#      'DEC 17, 1960',
#      'BOS vs. LAL',
#      'W',
#      None,
#      None,
#      None,
#      240,
#      56,
#      139,
#      0.403,
#      0,
#      0,
#      None,
#      28,
#      38,
#      0.737,
#      0,
#      None,
#      0,
#      28,
#      0,
#      0,
#      0,
#      28,
#      140],
#     [1610612738,
#      '0026000110',
#      'DEC 15, 1960',
#      'BOS vs. SYR',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      43,
#      None,
#      None,
#      None,
#      None,
#      None,
#      29,
#      47,
#      0.617,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      25,
#      115],
#     [1610612738,
#      '0026000104',
#      'DEC 13, 1960',
#      'BOS @ NYK',
#      'L',
#      None,
#      None,
#      None,
#      0,
#      42,
#      None,
#      None,
#      None,
#      None,
#      None,
#      31,
#      46,
#      0.674,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      33,
#      115],
#     [1610612738,
#      '0026000101',
#      'DEC 10, 1960',
#      'BOS @ PHW',
#      'L',
#      None,
#      None,
#      None,
#      0,
#      35,
#      None,
#      None,
#      None,
#      None,
#      None,
#      27,
#      None,
#      None,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      25,
#      97],
#     [1610612738,
#      '0026000097',
#      'DEC 09, 1960',
#      'BOS vs. CIN',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      65,
#      None,
#      None,
#      None,
#      None,
#      None,
#      16,
#      22,
#      0.727,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      29,
#      146],
#     [1610612738,
#      '0026000095',
#      'DEC 08, 1960',
#      'BOS @ CIN',
#      'L',
#      None,
#      None,
#      None,
#      0,
#      44,
#      None,
#      None,
#      None,
#      None,
#      None,
#      27,
#      36,
#      0.75,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      30,
#      115],
#     [1610612738,
#      '0026000092',
#      'DEC 07, 1960',
#      'BOS vs. SYR',
#      'L',
#      None,
#      None,
#      None,
#      0,
#      50,
#      None,
#      None,
#      None,
#      None,
#      None,
#      34,
#      42,
#      0.81,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      24,
#      134],
#     [1610612738,
#      '0026000088',
#      'DEC 05, 1960',
#      'BOS @ LAL',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      47,
#      114,
#      0.412,
#      None,
#      None,
#      None,
#      29,
#      35,
#      0.829,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      27,
#      123],
#     [1610612738,
#      '0026000087',
#      'DEC 04, 1960',
#      'BOS @ LAL',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      44,
#      115,
#      0.383,
#      None,
#      None,
#      None,
#      25,
#      35,
#      0.714,
#      None,
#      None,
#      0,
#      0,
#      None,
#      None,
#      None,
#      19,
#      113],
#     [1610612738,
#      '0026000083',
#      'DEC 02, 1960',
#      'BOS vs. LAL',
#      'L',
#      None,
#      None,
#      None,
#      0,
#      45,
#      None,
#      None,
#      None,
#      None,
#      None,
#      27,
#      29,
#      0.931,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      27,
#      117],
#     [1610612738,
#      '0026000081',
#      'DEC 01, 1960',
#      'BOS @ NYK',
#      'L',
#      None,
#      None,
#      None,
#      0,
#      45,
#      None,
#      None,
#      None,
#      None,
#      None,
#      21,
#      29,
#      0.724,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      27,
#      111],
#     [1610612738,
#      '0026000078',
#      'NOV 30, 1960',
#      'BOS @ DET',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      50,
#      None,
#      None,
#      None,
#      None,
#      None,
#      25,
#      36,
#      0.694,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      26,
#      125],
#     [1610612738,
#      '0026000074',
#      'NOV 29, 1960',
#      'BOS @ STL',
#      'W',
#      None,
#      None,
#      None,
#      240,
#      45,
#      107,
#      0.421,
#      None,
#      None,
#      None,
#      29,
#      38,
#      0.763,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      25,
#      119],
#     [1610612738,
#      '0026000068',
#      'NOV 26, 1960',
#      'BOS vs. SYR',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      45,
#      127,
#      0.354,
#      None,
#      None,
#      None,
#      39,
#      52,
#      0.75,
#      None,
#      None,
#      0,
#      25,
#      None,
#      None,
#      None,
#      25,
#      129],
#     [1610612738,
#      '0026000065',
#      'NOV 25, 1960',
#      'BOS @ NYK',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      43,
#      None,
#      None,
#      None,
#      None,
#      None,
#      25,
#      31,
#      0.806,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      22,
#      111],
#     [1610612738,
#      '0026000061',
#      'NOV 24, 1960',
#      'BOS @ PHW',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      52,
#      None,
#      None,
#      None,
#      None,
#      None,
#      28,
#      41,
#      0.683,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      27,
#      132],
#     [1610612738,
#      '0026000060',
#      'NOV 23, 1960',
#      'BOS vs. NYK',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      47,
#      None,
#      None,
#      None,
#      None,
#      None,
#      28,
#      None,
#      None,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      28,
#      122],
#     [1610612738,
#      '0026000055',
#      'NOV 20, 1960',
#      'BOS @ CIN',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      49,
#      None,
#      None,
#      None,
#      None,
#      None,
#      22,
#      31,
#      0.71,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      19,
#      120],
#     [1610612738,
#      '0026000053',
#      'NOV 19, 1960',
#      'BOS @ SYR',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      45,
#      None,
#      None,
#      None,
#      None,
#      None,
#      0,
#      0,
#      0.0,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      24,
#      114],
#     [1610612738,
#      '0026000044',
#      'NOV 16, 1960',
#      'BOS vs. STL',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      49,
#      None,
#      None,
#      None,
#      None,
#      None,
#      26,
#      39,
#      0.667,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      22,
#      124],
#     [1610612738,
#      '0026000042',
#      'NOV 15, 1960',
#      'BOS @ DET',
#      'L',
#      None,
#      None,
#      None,
#      0,
#      47,
#      None,
#      None,
#      None,
#      None,
#      None,
#      20,
#      23,
#      0.87,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      28,
#      114],
#     [1610612738,
#      '0026000035',
#      'NOV 12, 1960',
#      'BOS vs. LAL',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      48,
#      None,
#      None,
#      None,
#      None,
#      None,
#      35,
#      None,
#      None,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      33,
#      131],
#     [1610612738,
#      '0026000033',
#      'NOV 11, 1960',
#      'BOS vs. CIN',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      53,
#      None,
#      None,
#      None,
#      None,
#      None,
#      22,
#      28,
#      0.786,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      21,
#      128],
#     [1610612738,
#      '0026000028',
#      'NOV 08, 1960',
#      'BOS @ CIN',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      50,
#      None,
#      None,
#      None,
#      None,
#      None,
#      36,
#      49,
#      0.735,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      29,
#      136],
#     [1610612738,
#      '0026000025',
#      'NOV 05, 1960',
#      'BOS vs. CIN',
#      'L',
#      None,
#      None,
#      None,
#      240,
#      41,
#      8,
#      5.125,
#      None,
#      None,
#      None,
#      22,
#      41,
#      0.537,
#      None,
#      None,
#      0,
#      17,
#      None,
#      None,
#      None,
#      1,
#      104],
#     [1610612738,
#      '0026000017',
#      'OCT 29, 1960',
#      'BOS vs. PHW',
#      'L',
#      None,
#      None,
#      None,
#      0,
#      43,
#      132,
#      0.326,
#      None,
#      None,
#      None,
#      17,
#      26,
#      0.654,
#      None,
#      None,
#      0,
#      20,
#      None,
#      None,
#      None,
#      26,
#      103],
#     [1610612738,
#      '0026000014',
#      'OCT 28, 1960',
#      'BOS @ NYK',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      46,
#      None,
#      None,
#      None,
#      None,
#      None,
#      18,
#      22,
#      0.818,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      24,
#      110],
#     [1610612738,
#      '0026000005',
#      'OCT 22, 1960',
#      'BOS vs. DET',
#      'W',
#      None,
#      None,
#      None,
#      0,
#      43,
#      None,
#      None,
#      None,
#      None,
#      None,
#      32,
#      None,
#      None,
#      None,
#      None,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      118]]}]}

# %%
len(a["resultSets"][0]["rowSet"])
# Out:
# 82

# %%
seasons = [str(yr) + "-" + str(yr+1)[2:4] for yr in range(1990, 2023)]
teams = pd.read_csv(db_path + "teams.csv").id.to_list()
types = ["Regular Season","Pre Season","Playoffs","Preseason"]
list = []
for season in seasons:
    print (season)
    for team in teams:
        for type in types:
            for game in teamgamelog.TeamGameLog(season=season,season_type_all_star=type,team_id=team).get_dict()["resultSets"][0]["rowSet"]:
                list.append({"game_id":game[1],"season":season,"game_type":type,"team_id":game[0],"game_date":game[2],"matchup":game[3],"WL":game[4]})
# Out:
# 1990-91
# 1991-92
# 1992-93
# 1993-94
# 1994-95
# 1995-96
# 1996-97
# 1997-98
# 1998-99
# 1999-00
# 2000-01
# 2001-02
# 2002-03
# 2003-04
# 2004-05
# 2005-06
# 2006-07
# 2007-08
# 2008-09
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1075, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1074             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1075         self.do_handshake()
#    1076 except (OSError, ValueError):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#
# TimeoutError: _ssl.c:975: The handshake operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\packages\six.py:770, in reraise(tp, value, tb)
#     769         raise value.with_traceback(tb)
# --> 770     raise value
#     771 finally:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:389, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
# --> 389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#     390     raise
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:340, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     339 if isinstance(err, SocketTimeout):
# --> 340     raise ReadTimeoutError(
#     341         self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     342     )
#     344 # See the above comment about EAGAIN in Python 3. In Python 2 we have
#     345 # to specifically catch it and throw the timeout error
#
# ReadTimeoutError: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[115], line 9
#       7 for team in teams:
#       8     for type in types:
# ----> 9         for game in teamgamelog.TeamGameLog(season=season,season_type_all_star=type,team_id=team).get_dict()["resultSets"][0]["rowSet"]:
#      10             list.append({"game_id":game[1],"season":season,"game_type":type,"team_id":game[0],"game_date":game[2],"matchup":game[3],"WL":game[4]})
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\nba_api\stats\endpoints\teamgamelog.py:40, in TeamGameLog.__init__(self, team_id, season, season_type_all_star, date_from_nullable, date_to_nullable, league_id_nullable, proxy, headers, timeout, get_request)
#      31 self.parameters = {
#      32         'TeamID': team_id,
#      33         'Season': season,
#    (...)
#      37         'LeagueID': league_id_nullable
#      38 }
#      39 if get_request:
# ---> 40     self.get_request()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\nba_api\stats\endpoints\teamgamelog.py:43, in TeamGameLog.get_request(self)
#      42 def get_request(self):
# ---> 43     self.nba_response = NBAStatsHTTP().send_api_request(
#      44         endpoint=self.endpoint,
#      45         parameters=self.parameters,
#      46         proxy=self.proxy,
#      47         headers=self.headers,
#      48         timeout=self.timeout,
#      49     )
#      50     self.load_response()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\nba_api\library\http.py:130, in NBAHTTP.send_api_request(self, endpoint, parameters, referer, proxy, headers, timeout, raise_exception_on_error)
#     127         print('loading from file...')
#     129 if not contents:
# --> 130     response = requests.get(url=base_url, params=parameters, headers=request_headers, proxies=proxies, timeout=timeout)
#     131     url = response.url
#     132     status_code = response.status_code
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\adapters.py:532, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     530     raise SSLError(e, request=request)
#     531 elif isinstance(e, ReadTimeoutError):
# --> 532     raise ReadTimeout(e, request=request)
#     533 elif isinstance(e, _InvalidHeader):
#     534     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)

# %%
games = pd.DataFrame(list)
games
# Out:
#         season     team_id     game_id     game_date      matchup WL
# 0      1990-91  1610612737  0029001105  APR 21, 1991    ATL @ BOS  W
# 1      1990-91  1610612737  0029001092  APR 19, 1991  ATL vs. DET  L
# 2      1990-91  1610612737  0029001073  APR 17, 1991  ATL vs. CHH  L
# 3      1990-91  1610612737  0029001069  APR 16, 1991    ATL @ ORL  L
# 4      1990-91  1610612737  0029001047  APR 13, 1991  ATL vs. MIL  W
# ...        ...         ...         ...           ...          ... ..
# 89109  2022-23  1610612766  0012200054  OCT 12, 2022    CHA @ PHI  L
# 89110  2022-23  1610612766  0012200043  OCT 10, 2022  CHA vs. WAS  L
# 89111  2022-23  1610612766  0012200029  OCT 07, 2022  CHA vs. BOS  L
# 89112  2022-23  1610612766  0012200018  OCT 05, 2022  CHA vs. IND  L
# 89113  2022-23  1610612766  0012200005  OCT 02, 2022    CHA @ BOS  L
#
# [89114 rows x 6 columns]

# %%
len(games["game_id"].unique())
# Out:
# 42944

# %%
maybe = games.drop_duplicates(ignore_index=True)
maybe
# Out:
#         season     team_id     game_id     game_date      matchup WL
# 0      1990-91  1610612737  0029001105  APR 21, 1991    ATL @ BOS  W
# 1      1990-91  1610612737  0029001092  APR 19, 1991  ATL vs. DET  L
# 2      1990-91  1610612737  0029001073  APR 17, 1991  ATL vs. CHH  L
# 3      1990-91  1610612737  0029001069  APR 16, 1991    ATL @ ORL  L
# 4      1990-91  1610612737  0029001047  APR 13, 1991  ATL vs. MIL  W
# ...        ...         ...         ...           ...          ... ..
# 85757  2022-23  1610612766  0012200054  OCT 12, 2022    CHA @ PHI  L
# 85758  2022-23  1610612766  0012200043  OCT 10, 2022  CHA vs. WAS  L
# 85759  2022-23  1610612766  0012200029  OCT 07, 2022  CHA vs. BOS  L
# 85760  2022-23  1610612766  0012200018  OCT 05, 2022  CHA vs. IND  L
# 85761  2022-23  1610612766  0012200005  OCT 02, 2022    CHA @ BOS  L
#
# [85762 rows x 6 columns]

# %%
for game in games["game_id"].unique():
    subset = games.loc[games["game_id"]==game, ]
    if (len(z.index) == 1):
        print (z)

# %%
for game in games["game_id"].unique():
    subset = games.loc[games["game_id"]==game, ]
    if (len(z.index) > 2):
        print (z)
